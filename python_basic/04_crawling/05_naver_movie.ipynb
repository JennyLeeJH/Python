# %%
import requests, re, urllib.request
from bs4 import BeautifulSoup

# %%
url = 'https://movie.naver.com/movie/point/af/list.naver?&page={}'
reviewlist = []
for i in range(1,11):
    print(url.format(i))
    res = requests.get(url.format(i)).text
    # print(res)
    soup = BeautifulSoup(res, 'lxml')
    table = soup.find('table', class_='list_netizen')
    for i,r in enumerate(table.select('tbody tr')): #index가 필요하니 enumerate
        # print(i)
        # print(r)
        for j,c in enumerate(r.find_all('td')):
            if j == 0:
                record = int(c.text.strip())
                print('글번호 : ', record)
            elif j == 1:
                record1 = c.select_one('a').text.strip()
                print('영화제목 : ', record1)
                record2 = c.select_one('em').text
                print('영화평점 : ', record2)
                record3 = c.text
                record3 = record3.replace(record1, '')
                record3 = record3.replace('신고', '')
                record3 = re.sub('별점 - 총 10점 중 [0-9]{1,2}','',record3).strip()
                print(record3)
                try:
                    movie_dic = {
                        '제목' : record1,
                        '평점' : record2,
                        '감상평' : record3
                    }
                    reviewlist.append(movie_dic)
                except:
                    pass
print(reviewllist)
# Out:
# https://movie.naver.com/movie/point/af/list.naver?&page=1
# 글번호 :  18203709
# 영화제목 :  헤어질 결심
# 영화평점 :  9
# 별점 - 총 10점 중9
#
# 생각을 많이 하게되는 작품입니다
# 글번호 :  18203708
# 영화제목 :  탑건: 매버릭
# 영화평점 :  10
# 별점 - 총 10점 중10
#
# 진짜 이영화 속편을 30여년만에 다시보게해주신 톰오빠께 감사드려요ㅠㅠ 꼬꼬마때  눈이 땡그래져서 재미나게보던 감동의 수십배를 느끼며 다시봤어요.이루 표현할수없던 오프닝의 1편메인테마곡 ,오토바이씬은 진짜 극장안에서 울컥하면서 봤습니다ㅠㅠ 꼭 꼭 아이맥스로 봐야하는 영화에요.ott에풀리면 또봐야겠어요.진짜 존경스럽네요ㅠㅠ
# 글번호 :  18203707
# 영화제목 :  탑건: 매버릭
# 영화평점 :  10
# 별점 - 총 10점 중10
#
# 진짜 미쳤음전투기 액션을 이렇게 만들 수 있구나 싶었음 꼭 보세요~~
# 글번호 :  18203706
# 영화제목 :  헤어질 결심
# 영화평점 :  10
# 별점 - 총 10점 중10
#
# 최고다 보는 내내 박해일 탕웨이 표정연기에 빠졌다
# 글번호 :  18203705
# 영화제목 :  탑건: 매버릭
# 영화평점 :  10
# 별점 - 총 10점 중10
#
# 톰의 한계가 어디까지인지 ... 진심 대단합니다!
# 글번호 :  18203704
# 영화제목 :  액션히어로
# 영화평점 :  5
# 별점 - 총 10점 중5
#
# 수면부족 중 보다자다...;;;
# 글번호 :  18203703
# 영화제목 :  탑건: 매버릭
# 영화평점 :  10
# 별점 - 총 10점 중10
#
# 이런게 10점짜리지. 다른 영화는 진짜 뻥튀기다. 국뽕 적당히 하자
# 글번호 :  18203702
# 영화제목 :  탑건: 매버릭
# 영화평점 :  10
# 별점 - 총 10점 중10
#
# 30년의 기억이 주마등처럼…
# 글번호 :  18203701
# ...
